# %%
a=60
b=50
c=a+b
print(c)
# Out:
# 110

# %%
# Contact Book app in python 

contacts={


}

while True:
    print("press 1.Add Contact")
    print("press 2.View Contacts")
    print("press 3.Search Contact")
    print("press 4.Delete Contact")
    print("press 5.update contact")
    print("press 6.Count Contacts")
    print("press 7.Exit")
    choice = input("Enter your choice:")

    # Add Contact 

    if choice==1:
        name=input("Enter name:")
    if name is already in contacts:
        print("cotact is already in contacts")
    else:
        phone=input("enter the phone number=")
        email=input("enter the email=")
        contacts[name] = {"phone": phone, "email": email}
        print("Contact added successfully!")

    #view contacts

     elif choice=="2":
        if not contacts:
            print("NO CONTACTS FOUND")

        else:
            print("/n--Contacts--")
            for namem, details in contacts.items():
                print("Name=",name)
                print("Phone=",phone)
                print("Email=",email)
                print("--------------------")
    # search contacts 

    elif choice=="3":
        search=input("entern the name to search=")
        if seach in contacts:
            prrint("Contact Found")
               print(f"Name: {search_name}")
            print(f"Phone: {contacts[search_name]['Phone']}")
              print(f"Email: {contacts[search_name]['Email']}")
        else:
            print("Contact not found")

    # delete contact

    elif choice=="4":
        delete_name=input("Enter the name to delete=")
        if delete_name in contacts:
            del contacts[delete_name]
            print("Contact deleted successfully!")
        else:
            print("Contact not found")

# update contact

    elif choice=="5":
        update_name=input("Enter the name to update=")
        if update_name in contacts:
            phone=input("Enter the new phone number=")
            email=input("Enter the new email=")
            contacts[update_name] = {"phone": phone, "email": email}
            print("Contact updated successfully!")
        else:
            print("Contact not found")

    # count contacts

    elif choice=="6":
        count=len(contacts)
        print(f"Total contacts: {count}")

    # exit

    elif choice=="7":
        print("Exiting...")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
#   File <string>:32
#     elif choice=="2":
#                      ^
# IndentationError: unindent does not match any outer indentation level

# %%
# File manager in python 

import os 

while True:
    print("press 1 for create a file")
    print("press 2 for read a file")
    print("press 3 for update a file")
    print("press 4 for delete a file")
    print("press 5 for exit")

    choice=int(input("enter the choice"))

    if choice=="1":
        filename=input("enter the file name")
        content=input("enter the file content")
        with open(filename,"W") as file:
            file.write(content)
            print("File Created successfully")
    
    elif  choice=="2":
        fileename=input("enter the filename to read")
        if as path.exists(filename):
            with open(filename)as file:
                content=filename.read()
                print("fiule content")
                print(content)
        else:
            print("file not found")
    
    elif choice=="3":
        filename=input("enter the filename to update")
        if as.path.exists(filename):
            content=input("enter the new content")
            with open(filename,"a") as file:
                file.write(content)
                print("file updated successfully")
        else:
            print("file not found")

    elif choice=="4":
        filename=input("enter the filename to delete")
        if as.path.exists(filename):
            as.remove(filename)
            print("file deleted successfully")
        else:
            print("file not found")

    elif choice=="5":
        print("existing.....")
        break
# Out:
#   Cell In[1], line 23
#     if as path.exists(filename):
#        ^
# SyntaxError: invalid syntax

# %%
patients = {}

while True:
    print("1. Add Patient")
    print("2. View Patients")
    print("3. Exit")

    choice = input("Enter choice: ")

    if choice == "1":
        name = input("Patient Name: ")
        age = input("Age: ")
        patients[name] = age

    elif choice == "2":
        print(patients)

    elif choice == "3":
        break
# Out:
# 1. Add Patient
# 2. View Patients
# 3. Exit
# 1. Add Patient
# 2. View Patients
# 3. Exit
# {'mohit ': '17'}
# 1. Add Patient
# 2. View Patients
# 3. Exit
