# %%
a=10
b=10
c=a+b
print(c)
# Out:
# 20

# %%
# project code for patient record management system

(press 1 for add patient record),
(press 2 for view patient record),
(press 3 for update patient record),
(press 4 for delete patient record)

def add_patient():
    id=int(input("enter the id="))
    name=input("enter the name=")
    phone=int(input("enter the phone number "))
    address=int(input("enter the adddress="))

if choice==1(for add patient  record):

    id=int(input("enter the id="))
    name=input("enter the name=")
    phone=int(input("enter the phone number "))
    address=int(input("enter the adddress="))

elif:
print("Patient added successfully")

if choice==2(for view patient record):
    id=int(input("enter the id="))
    name=input("enter the name=")
elif:
    print("Patient record found")
else:
    print("Patient record not found")

if choice==3(for update patient record):
    id=int(input("enter the id="))
    name=input("enter the name=")
    phone=int(input("enter the phone number "))
    address=int(input("enter the adddress="))
elif:
   print("Patient record updated successfully")
else:
    print("Patient record not found")

if choice==4(for delete patient record):
    id=int(input("enter the id="))
    name=input("enter the name=")
elif:
    print("Patient record deleted successfully")
else:
    print("Patient record not found")
# Out:
#   Cell In[1], line 3
#     (press 1 for add patient record),
#      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
