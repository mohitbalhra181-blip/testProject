# %%
# Simple File Manager in Python

import os

while True:
    print("\n===== FILE MANAGER =====")
    print("1. Create File")
    print("2. Read File")
    print("3. Delete File")
    print("4. Rename File")
    print("5. List Files")
    print("6. Exit")

    choice = input("Enter your choice: ")

    # Create File
    if choice == "1":
        filename = input("Enter file name: ")

        with open(filename, "w") as file:
            content = input("Enter content for file: ")
            file.write(content)

        print("File created successfully!")

    # Read File
    elif choice == "2":
        filename = input("Enter file name to read: ")

        if os.path.exists(filename):
            with open(filename, "r") as file:
                print("\nFile Content:\n")
                print(file.read())
        else:
            print("File does not exist!")

    # Delete File
    elif choice == "3":
        filename = input("Enter file name to delete: ")

        if os.path.exists(filename):
            os.remove(filename)
            print("File deleted successfully!")
        else:
            print("File does not exist!")

    # Rename File
    elif choice == "4":
        old_name = input("Enter current file name: ")
        new_name = input("Enter new file name: ")

        if os.path.exists(old_name):
            os.rename(old_name, new_name)
            print("File renamed successfully!")
        else:
            print("File does not exist!")

    # List Files
    elif choice == "5":
        files = os.listdir()

        print("\nFiles in Current Folder:\n")

        for file in files:
            print(file)

    # Exit
    elif choice == "6":
        print("Exiting File Manager...")
        break

    else:
        print("Invalid choice! Try again.")
# Out:
# ===== FILE MANAGER =====
# 1. Create File
# 2. Read File
# 3. Delete File
# 4. Rename File
# 5. List Files
# 6. Exit
# File created successfully!
#
# ===== FILE MANAGER =====
# 1. Create File
# 2. Read File
# 3. Delete File
# 4. Rename File
# 5. List Files
# 6. Exit
#
# File Content:
#
# songs
#
# ===== FILE MANAGER =====
# 1. Create File
# 2. Read File
# 3. Delete File
# 4. Rename File
# 5. List Files
# 6. Exit
#
# Files in Current Folder:
#
# .venv-1
# balhra.ipynb
# contact book .ipynb
# file manager.ipynb
# index.ipynb
# mohit.ipynb
# mohit2.ipynb
# mohitbalhra.ipynb
# music
#
# ===== FILE MANAGER =====
# 1. Create File
# 2. Read File
# 3. Delete File
# 4. Rename File
# 5. List Files
# 6. Exit
# Invalid choice! Try again.
#
# ===== FILE MANAGER =====
# 1. Create File
# 2. Read File
# 3. Delete File
# 4. Rename File
# 5. List Files
# 6. Exit
# Exiting File Manager...

# %%
# rent calculator 
# Rent Calculator in Python

print("===== RENT CALCULATOR =====")

# Inputs
room_rent = int(input("Enter room rent: "))
food_bill = int(input("Enter food bill: "))
electricity_units = int(input("Enter electricity units used: "))
charge_per_unit = int(input("Enter charge per unit: "))
persons = int(input("Enter number of persons: "))

# Electricity bill
electricity_bill = electricity_units * charge_per_unit

# Total expense
total_bill = room_rent + food_bill + electricity_bill

# Per person amount
per_person = total_bill / persons

# Output
print("\n===== BILL DETAILS =====")
print(f"Room Rent: ₹{room_rent}")
print(f"Food Bill: ₹{food_bill}")
print(f"Electricity Bill: ₹{electricity_bill}")
print(f"Total Bill: ₹{total_bill}")
print(f"Each Person Should Pay: ₹{per_person}")
# Out:
# ===== RENT CALCULATOR =====
#
# ===== BILL DETAILS =====
# Room Rent: ₹5000
# Food Bill: ₹1000
# Electricity Bill: ₹400
# Total Bill: ₹6400
# Each Person Should Pay: ₹1600.0

# %%
    # Contact Book App in Python

    contacts = {}

    while True:
        print("\n===== CONTACT BOOK =====")
        print("1. Add Contact")
        print("2. View Contacts")
        print("3. Search Contact")
        print("4. Update Contact")
        print("5. Delete Contact")
        print("6. Count Contacts")
        print("7. Exit")

        choice = input("Enter your choice: ")

        # Add Contact
        if choice == "1":
            name = input("Enter name: ")
            if name in contacts:
                print("Contact already exists!")
            else:
                phone = input("Enter phone number: ")
                email = input("Enter email: ")
                contacts[name] = {
                    "Phone": phone,
                    "Email": email
                }
                print("Contact added successfully!")

        # View Contacts
        elif choice == "2":
            if not contacts:
                print("No contacts found!")
            else:
                print("\n--- Contact List ---")
                for name, details in contacts.items():
                    print(f"Name: {name}")
                    print(f"Phone: {details['Phone']}")
                    print(f"Email: {details['Email']}")
                    print("-------------------")

        # Search Contact
        elif choice == "3":
            search_name = input("Enter name to search: ")
            if search_name in contacts:
                print("\nContact Found!")
                print(f"Name: {search_name}")
                print(f"Phone: {contacts[search_name]['Phone']}")
                print(f"Email: {contacts[search_name]['Email']}")
            else:
                print("Contact not found!")

        # Update Contact
        elif choice == "4":
            update_name = input("Enter name to update: ")
            if update_name in contacts:
                new_phone = input("Enter new phone number: ")
                new_email = input("Enter new email: ")

                contacts[update_name]["Phone"] = new_phone
                contacts[update_name]["Email"] = new_email

                print("Contact updated successfully!")
            else:
                print("Contact not found!")

        # Delete Contact
        elif choice == "5":
            delete_name = input("Enter name to delete: ")
            if delete_name in contacts:
                del contacts[delete_name]
                print("Contact deleted successfully!")
            else:
                print("Contact not found!")

        # Count Contacts
        elif choice == "6":
            print(f"Total contacts: {len(contacts)}")

        # Exit
        elif choice == "7":
            print("Thank you for using Contact Book!")
            break

        else:
            print("Invalid choice! Please try again.")
# Out:
# ===== CONTACT BOOK =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Count Contacts
# 7. Exit
# Contact added successfully!
#
# ===== CONTACT BOOK =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Count Contacts
# 7. Exit
# Contact added successfully!
#
# ===== CONTACT BOOK =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Count Contacts
# 7. Exit
# Thank you for using Contact Book!

# %%
# Student Management System in Python

students = {}

while True:
    print("\n===== STUDENT MANAGEMENT SYSTEM =====")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Delete Student")
    print("6. Count Students")
    print("7. Exit")

    choice = input("Enter your choice: ")

    # Add Student
    if choice == "1":
        roll_no = input("Enter Roll Number: ")

        if roll_no in students:
            print("Student already exists!")
        else:
            name = input("Enter Name: ")
            age = input("Enter Age: ")
            course = input("Enter Course: ")

            students[roll_no] = {
                "Name": name,
                "Age": age,
                "Course": course
            }

            print("Student added successfully!")

    # View Students
    elif choice == "2":
        if not students:
            print("No student records found!")
        else:
            print("\n===== STUDENT RECORDS =====")

            for roll_no, details in students.items():
                print(f"\nRoll No: {roll_no}")
                print(f"Name: {details['Name']}")
                print(f"Age: {details['Age']}")
                print(f"Course: {details['Course']}")

    # Search Student
    elif choice == "3":
        roll_no = input("Enter Roll Number to search: ")

        if roll_no in students:
            print("\nStudent Found!")
            print(f"Name: {students[roll_no]['Name']}")
            print(f"Age: {students[roll_no]['Age']}")
            print(f"Course: {students[roll_no]['Course']}")
        else:
            print("Student not found!")

    # Update Student
    elif choice == "4":
        roll_no = input("Enter Roll Number to update: ")

        if roll_no in students:
            name = input("Enter New Name: ")
            age = input("Enter New Age: ")
            course = input("Enter New Course: ")

            students[roll_no] = {
                "Name": name,
                "Age": age,
                "Course": course
            }

            print("Student updated successfully!")
        else:
            print("Student not found!")

    # Delete Student
    elif choice == "5":
        roll_no = input("Enter Roll Number to delete: ")

        if roll_no in students:
            del students[roll_no]
            print("Student deleted successfully!")
        else:
            print("Student not found!")

    # Count Students
    elif choice == "6":
        print(f"Total Students: {len(students)}")

    # Exit
    elif choice == "7":
        print("Exiting Student Management System...")
        break

    else:
        print("Invalid choice! Please try again.")
# Out:
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Count Students
# 7. Exit
# Student added successfully!
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Count Students
# 7. Exit
# Student added successfully!
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Count Students
# 7. Exit
#
# ===== STUDENT RECORDS =====
#
# Roll No: 1024337233
# Name: mohit
# Age: 17
# Course: BCA
#
# Roll No: 123456789
# Name: roghu
# Age: 15
# Course: B.Tech
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Count Students
# 7. Exit
# Total Students: 2
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Count Students
# 7. Exit
# Exiting Student Management System...

# %%
# TO-DO List App in Python

tasks = []

while True:
    print("\n===== TO-DO LIST APP =====")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Remove Task")
    print("4. Clear All Tasks")
    print("5. Exit")

    choice = input("Enter your choice: ")

    # Add Task
    if choice == "1":
        task = input("Enter new task: ")
        tasks.append(task)
        print("Task added successfully!")

    # View Tasks
    elif choice == "2":
        if not tasks:
            print("No tasks available!")
        else:
            print("\n===== YOUR TASKS =====")

            for index, task in enumerate(tasks, start=1):
                print(f"{index}. {task}")

    # Remove Task
    elif choice == "3":
        if not tasks:
            print("No tasks to remove!")
        else:
            print("\n===== TASKS =====")

            for index, task in enumerate(tasks, start=1):
                print(f"{index}. {task}")

            task_no = int(input("Enter task number to remove: "))

            if 1 <= task_no <= len(tasks):
                removed_task = tasks.pop(task_no - 1)
                print(f"Task '{removed_task}' removed successfully!")
            else:
                print("Invalid task number!")

    # Clear All Tasks
    elif choice == "4":
        tasks.clear()
        print("All tasks cleared!")

    # Exit
    elif choice == "5":
        print("Exiting TO-DO List App...")
        break

    else:
        print("Invalid choice! Please try again.")
# Out:
# ===== TO-DO LIST APP =====
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Clear All Tasks
# 5. Exit
# Task added successfully!
#
# ===== TO-DO LIST APP =====
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Clear All Tasks
# 5. Exit
# Task added successfully!
#
# ===== TO-DO LIST APP =====
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Clear All Tasks
# 5. Exit
# Task added successfully!
#
# ===== TO-DO LIST APP =====
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Clear All Tasks
# 5. Exit
# Task added successfully!
#
# ===== TO-DO LIST APP =====
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Clear All Tasks
# 5. Exit
#
# ===== YOUR TASKS =====
# 1. study
# 2. practice
# 3. gym
# 4. sleep
#
# ===== TO-DO LIST APP =====
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Clear All Tasks
# 5. Exit
# Exiting TO-DO List App...

# %%
#password generator 

import random
import string

length = int(input("Enter password length: "))

characters = string.ascii_letters + string.digits + string.punctuation

password = "".join(random.choice(characters) for i in range(length))

print("Generated Password:", password)
# Out:
# Generated Password: sF0m`xdl

# %%
# Daily Expense Manager

expenses = []

while True:
    print("\n===== DAILY EXPENSE MANAGER =====")
    print("1. Add Expense")
    print("2. View Expenses")
    print("3. Show Total Expense")
    print("4. Exit")

    choice = input("Enter your choice (1-4): ")

    if choice == "1":
        item = input("Enter expense name: ")
        amount = float(input("Enter amount: ₹"))

        expenses.append({
            "item": item,
            "amount": amount
        })

        print("Expense added successfully!")

    elif choice == "2":
        if not expenses:
            print("No expenses recorded.")
        else:
            print("\n--- Expense List ---")
            for i, expense in enumerate(expenses, start=1):
                print(f"{i}. {expense['item']} - ₹{expense['amount']}")

    elif choice == "3":
        total = sum(expense["amount"] for expense in expenses)
        print(f"\nTotal Expense: ₹{total}")

    elif choice == "4":
        print("Thank you for using Daily Expense Manager!")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# ===== DAILY EXPENSE MANAGER =====
# 1. Add Expense
# 2. View Expenses
# 3. Show Total Expense
# 4. Exit
# Expense added successfully!
#
# ===== DAILY EXPENSE MANAGER =====
# 1. Add Expense
# 2. View Expenses
# 3. Show Total Expense
# 4. Exit
# Expense added successfully!
#
# ===== DAILY EXPENSE MANAGER =====
# 1. Add Expense
# 2. View Expenses
# 3. Show Total Expense
# 4. Exit
# Expense added successfully!
#
# ===== DAILY EXPENSE MANAGER =====
# 1. Add Expense
# 2. View Expenses
# 3. Show Total Expense
# 4. Exit
#
# --- Expense List ---
# 1. fuel - ₹3000.0
# 2. food - ₹10000.0
# 3. other - ₹20000.0
#
# ===== DAILY EXPENSE MANAGER =====
# 1. Add Expense
# 2. View Expenses
# 3. Show Total Expense
# 4. Exit
#
# Total Expense: ₹33000.0
#
# ===== DAILY EXPENSE MANAGER =====
# 1. Add Expense
# 2. View Expenses
# 3. Show Total Expense
# 4. Exit
# Thank you for using Daily Expense Manager!

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")
db = client["dbproject"]
collection = db["tbproject"]

class emp:
    def get(self,x,y):
        self.id=x
        self.salary=y
    def show(self):
        print("id=",self.id)
        print("salary=",self.salary)
    e1=emp()
    e2=emp()
e3=emp()

e1.get(101,10000)
e2.get(202,20000)
e3.get(303,30000)


e1.show()
e2.show()
e3.show()

code = """
print("Hello, World!")
"""

data = {
    "title": "Hello World Program",
    "language": "Python",
    "code": code
}

collection.insert_one(data)

print("Code saved successfully!")
# e1.id=101
# e2.id=202

# e1.salary=10000
# e2.salary=20000
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pymongo import MongoClient
#       2
#       3 client = MongoClient("mongodb://localhost:27017/")
#       4 db = client["dbproject"]
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
class emp:
    def get(self,x,y):
        self.id=x
        self.salary=y
    def show(self):
        print("id=",self.id)
        print("salary=",self.salary)
e1=emp()
e2=emp()
e3=emp()

e1.get(101,10000)
e2.get(202,20000)
e3.get(303,30000)


e1.show()
e2.show()
e3.show()
# Out:
# id= 101
# salary= 10000
# id= 202
# salary= 20000
# id= 303
# salary= 30000

# %%
class emp:
    def get(self):
        self.id=input("Enter the id=")
        self.salary=input("Enter the salary=")
    def show(self):
        print("id=",self.id)
        print("salary=",self.salary)
e1=emp()
e2=emp()
e3=emp()

e1.get()
e2.get()
e3.get()


e1.show()
e2.show()
e3.show()
# Out:
# id= 2222222
# salary= 50000
# id= 333333
# salary= 60000
# id=
# salary=

# %%
class Bank:
    def openAccount(self,x,y):
        self.accNo=x
        self.balance=y
    def deposit(self,money):
        self.balance=self.balance+money
    def withdrawl(self,money):
        if(money>self.balance):
            print("Insufficient Balance ")
        else:
            self.balance=self.balance-money    
    def showBalance(self):
        print("account No=",self.accNo)
        print("Balance=",self.balance)
        
cust1=Bank()
cust2=Bank()
cust3=Bank()

cust1.openAccount(101,10000)
cust2.openAccount(202,20000)
cust3.openAccount(303,30000)

cust1.deposit(5000)

cust1.withdrawl(4000)


cust1.showBalance()
# cust2.showBalance()
# cust3.showBalance()
# Out:
# account No= 101
# Balance= 11000

# %%
class Bank:
    def openAccount(self,x,y):
        self.accNo=x
        self.balance=y
    def deposit(self,money):
        self.balance=self.balance+money
    def withdrawl(self,money):
        if(money>self.balance):
            print("Insufficient Balance ")
        else:
            self.balance=self.balance-money    
    def showBalance(self):
        print("account No=",self.accNo)
        print("Balance=",self.balance)
        
cust1=Bank()
cust2=Bank()
cust3=Bank()

cust1.openAccount(101,10000)
cust2.openAccount(202,20000)
cust3.openAccount(303,30000)

i=1
while(i):
    print("Press 1: for deposit=")
    print("Press 2: for withdrawl=")
    print("Press 3: for show balance=")
    choice=int(input("Enter your choice="))

    if(choice==1):
        print("Press 1: for customer 1")
        print("Press 2: for customer 2")
        print("Press 3: for customer 3")
        ch=int(input("Enter your choice="))
        money=int(input("Enter the money="))
        if(ch==1):
            cust1.deposit(money)
        elif(ch==2):
            cust2.deposit(money)
        elif(ch==3):
            cust3.deposit(money)
    elif(choice==2):
        pass
    elif(choice==3):
        print("Press 1: for customer 1")
        print("Press 2: for customer 2")
        print("Press 3: for customer 3")
        ch=int(input("Enter your choice="))
        if(ch==1):
            cust1.showBalance()
        elif(ch==2):
            cust2.showBalance()
        elif(ch==3):
            cust3.showBalance()
    else:
        print("Wrong Choice,,,, Trya again....")
    i=int(input("Press 1: for more , press 0: for exit= "))
# Out:
# Press 1: for deposit=
# Press 2: for withdrawl=
# Press 3: for show balance=
# Press 1: for customer 1
# Press 2: for customer 2
# Press 3: for customer 3
# Press 1: for deposit=
# Press 2: for withdrawl=
# Press 3: for show balance=
# Press 1: for customer 1
# Press 2: for customer 2
# Press 3: for customer 3
# Press 1: for deposit=
# Press 2: for withdrawl=
# Press 3: for show balance=
# Press 1: for customer 1
# Press 2: for customer 2
# Press 3: for customer 3
# Press 1: for deposit=
# Press 2: for withdrawl=
# Press 3: for show balance=
# Press 1: for customer 1
# Press 2: for customer 2
# Press 3: for customer 3
# account No= 303
# Balance= 30000
# Press 1: for deposit=
# Press 2: for withdrawl=
# Press 3: for show balance=
# Press 1: for customer 1
# Press 2: for customer 2
# Press 3: for customer 3
# account No= 101
# Balance= 130000

# %%
class demo:
    def get(self,x,y): # local variable
        self.a=x  # attribute
        self.b=y
    def show(self):
        print("a=",self.a)
        print("b=",self.b)
    def sum(self, ob1,ob2):
        self.a =ob1.a+ ob2.a
        self.b =ob1.b+ ob2.b 
obj1=demo()
obj2=demo()
obj3=demo()

obj1.get(10,20) # argument , parameter
obj2.get(30,40)


obj1.show()
obj2.show()


obj3.sum(obj1,obj2) # object a as argument
obj3.show()
# Out:
# a= 10
# b= 20
# a= 30
# b= 40
# a= 40
# b= 60

# %%
class demo:
    def get(self):
        self.a=int(input("enter the value of a="))
        self.b=int(input("enter the value of b="))
    def show (self):
        print("a=",self.a)
        print("b=",self.b)
obj1=demo()
obj2=demo()
obj3=demo()

obj1.get()
obj2.get()
obj3.get()

obj1.show()
obj2.show()
obj3.show()
# Out:
# a= 1
# b= 50000
# a= 2
# b= 60000
# a= 3
# b= 70000
# a= 3
# b= 110000

# %%
class demo:
    def get(self):
        self.a=int(input("enter the value of a="))
        self.b=int(input("enter the value of b="))
    def show (self):
        print("a=",self.a)
        print("b=",self.b)
    def sum(self,ob1,ob2):
        self.a=ob1.a+ob2.a
        self.b=ob1.b+ob2.b
obj1=demo()
obj2=demo()
obj3=demo()

obj1.get()
obj2.get()
obj3.get()

obj1.show()
obj2.show()
obj3.show()


obj3.sum(obj1,obj2)
obj3.show()
# Out:
# a= 1
# b= 20
# a= 2
# b= 40
# a= 3
# b= 60
# a= 3
# b= 60

# %%
import random

class Game:
    def play(self,p2,p3):
        cnum=int(random.random()*10)
        p1_match=0
        p2_match=0
        p3_match=0
        turn=1
        while(turn):
            print("Computer Generated Number is=",cnum)
            if(p1_match==0):
                self.num= int(random.random()*10)
                print("player1 Generated Number is=",self.num)
                if(cnum==self.num):
                    print("Player 1: won the match:")
                    p1_match=1
            if(p2_match==0):
                p2.num= int(random.random()*10)
                print("player2 Generated Number is=",p2.num)
                if(cnum==p2.num):
                    print("Player 2: won the match:")
                    p2_match=1
            if(p3_match==0):
                p3.num= int(random.random()*10)
                print("player3 Generated Number is=",p3.num)
                if(cnum==p3.num):
                    print("Player 3: won the match:")
                    p3_match=1

            print()            
                
            if(p1_match==1 and p2_match==1 and p3_match==1):
                turn=0
            

player1=Game()
player2=Game()
player3=Game()

player1.play(player2,player3)
# Out:
# Computer Generated Number is= 2
# player1 Generated Number is= 9
# player2 Generated Number is= 0
# player3 Generated Number is= 7
#
# Computer Generated Number is= 2
# player1 Generated Number is= 3
# player2 Generated Number is= 2
# Player 2: won the match:
# player3 Generated Number is= 4
#
# Computer Generated Number is= 2
# player1 Generated Number is= 7
# player3 Generated Number is= 9
#
# Computer Generated Number is= 2
# player1 Generated Number is= 4
# player3 Generated Number is= 6
#
# Computer Generated Number is= 2
# player1 Generated Number is= 3
# player3 Generated Number is= 1
#
# Computer Generated Number is= 2
# player1 Generated Number is= 4
# player3 Generated Number is= 3
#
# Computer Generated Number is= 2
# player1 Generated Number is= 2
# Player 1: won the match:
# player3 Generated Number is= 1
#
# Computer Generated Number is= 2
# player3 Generated Number is= 5
#
# Computer Generated Number is= 2
# player3 Generated Number is= 4
#
# Computer Generated Number is= 2
# player3 Generated Number is= 7
#
# Computer Generated Number is= 2
# player3 Generated Number is= 9
#
# Computer Generated Number is= 2
# player3 Generated Number is= 6
#
# Computer Generated Number is= 2
# player3 Generated Number is= 0
#
# Computer Generated Number is= 2
# player3 Generated Number is= 7
#
# Computer Generated Number is= 2
# player3 Generated Number is= 5
#
# Computer Generated Number is= 2
# player3 Generated Number is= 6
#
# Computer Generated Number is= 2
# player3 Generated Number is= 0
#
# Computer Generated Number is= 2
# player3 Generated Number is= 9
#
# Computer Generated Number is= 2
# player3 Generated Number is= 4
#
# Computer Generated Number is= 2
# player3 Generated Number is= 6
#
# Computer Generated Number is= 2
# player3 Generated Number is= 5
#
# Computer Generated Number is= 2
# player3 Generated Number is= 0
#
# Computer Generated Number is= 2
# player3 Generated Number is= 6
#
# Computer Generated Number is= 2
# player3 Generated Number is= 8
#
# Computer Generated Number is= 2
# player3 Generated Number is= 8
#
# Computer Generated Number is= 2
# player3 Generated Number is= 4
#
# Computer Generated Number is= 2
# player3 Generated Number is= 3
#
# Computer Generated Number is= 2
# player3 Generated Number is= 8
#
# Computer Generated Number is= 2
# player3 Generated Number is= 9
#
# Computer Generated Number is= 2
# player3 Generated Number is= 1
#
# Computer Generated Number is= 2
# player3 Generated Number is= 6
#
# Computer Generated Number is= 2
# player3 Generated Number is= 5
#
# Computer Generated Number is= 2
# player3 Generated Number is= 2
# Player 3: won the match:

# %%
  import random

class Game:
    def play(self,p2,p3):
        cnum=int(random.random()*10)
        p1_match=0
        p2_match=0
        p3_match=0
        turn=1
        while(turn):
            self.num= int(random.random()*10)
            p2.num= int(random.random()*10)
            p3.num= int(random.random()*10)

            print("Computer Generated Number is=",cnum)
            print("player1 Generated Number is=",self.num)
            print("player2 Generated Number is=",p2.num)
            print("player3 Generated Number is=",p3.num)
            print()
            if(cnum==self.num):
                print("Player 1: won the match:")
                p1_match=1
            if(cnum==p2.num):
                print("Player 2: won the match:")
                p2_match=1
            if(cnum==p3.num):
                print("Player 3: won the match:")
                p3_match=1
                
            if(p1_match==1 and p2_match==1 and p3_match==1):
                turn=0
            

player1=Game()
player2=Game()
player3=Game()

player1.play(player2,player3)
# Out:
# Computer Generated Number is= 9
# player1 Generated Number is= 4
# player2 Generated Number is= 5
# player3 Generated Number is= 5
#
# Computer Generated Number is= 9
# player1 Generated Number is= 7
# player2 Generated Number is= 5
# player3 Generated Number is= 3
#
# Computer Generated Number is= 9
# player1 Generated Number is= 4
# player2 Generated Number is= 6
# player3 Generated Number is= 1
#
# Computer Generated Number is= 9
# player1 Generated Number is= 2
# player2 Generated Number is= 6
# player3 Generated Number is= 4
#
# Computer Generated Number is= 9
# player1 Generated Number is= 4
# player2 Generated Number is= 5
# player3 Generated Number is= 1
#
# Computer Generated Number is= 9
# player1 Generated Number is= 9
# player2 Generated Number is= 7
# player3 Generated Number is= 2
#
# Player 1: won the match:
# Computer Generated Number is= 9
# player1 Generated Number is= 4
# player2 Generated Number is= 6
# player3 Generated Number is= 1
#
# Computer Generated Number is= 9
# player1 Generated Number is= 5
# player2 Generated Number is= 9
# player3 Generated Number is= 0
#
# Player 2: won the match:
# Computer Generated Number is= 9
# player1 Generated Number is= 3
# player2 Generated Number is= 1
# player3 Generated Number is= 2
#
# Computer Generated Number is= 9
# player1 Generated Number is= 0
# player2 Generated Number is= 3
# player3 Generated Number is= 4
#
# Computer Generated Number is= 9
# player1 Generated Number is= 9
# player2 Generated Number is= 7
# player3 Generated Number is= 9
#
# Player 1: won the match:
# Player 3: won the match:

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")
db = client["dbbank"]
accounts_collection = db["accounts"]

class BankAccount:
    def __init__(self, acc_no, name, password, balance=0):
        self.acc_no = acc_no
        self.name = name
        self.password = password
        self.balance = balance
        self.history = []

    def deposit(self, amount):
        self.balance += amount
        self.history.append(f"Deposited ₹{amount}")
        print("Deposit Successful!")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient Balance!")
        else:
            self.balance -= amount
            self.history.append(f"Withdrawn ₹{amount}")
            print("Withdrawal Successful!")

    def show_balance(self):
        print(f"Current Balance: ₹{self.balance}")

    def show_history(self):
        if not self.history:
            print("No Transactions Found!")
        else:
            print("\nTransaction History:")
            for item in self.history:
                print(item)


class Bank:
    def __init__(self):
        self.accounts = {}

    def create_account(self):
        acc_no = input("Enter Account Number: ")

        if acc_no in self.accounts:
            print("Account Already Exists!")
            return

        name = input("Enter Name: ")
        password = input("Create Password: ")
        balance = float(input("Initial Deposit: "))

        self.accounts[acc_no] = BankAccount(
            acc_no, name, password, balance
        )

        print("Account Created Successfully!")

    def login(self):
        acc_no = input("Account Number: ")
        password = input("Password: ")

        if acc_no in self.accounts:
            account = self.accounts[acc_no]

            if account.password == password:
                print(f"\nWelcome {account.name}")
                self.account_menu(account)
            else:
                print("Wrong Password!")
        else:
            print("Account Not Found!")

    def transfer_money(self, sender):
        receiver_acc = input("Receiver Account Number: ")

        if receiver_acc not in self.accounts:
            print("Receiver Account Not Found!")
            return

        amount = float(input("Enter Amount: "))

        if amount > sender.balance:
            print("Insufficient Balance!")
            return

        sender.balance -= amount
        self.accounts[receiver_acc].balance += amount

        sender.history.append(
            f"Transferred ₹{amount} to {receiver_acc}"
        )

        self.accounts[receiver_acc].history.append(
            f"Received ₹{amount} from {sender.acc_no}"
        )

        print("Transfer Successful!")

    def account_menu(self, account):
        while True:
            print("\n===== ACCOUNT MENU =====")
            print("1. Deposit")
            print("2. Withdraw")
            print("3. Check Balance")
            print("4. Transfer Money")
            print("5. Transaction History")
            print("6. Logout")

            choice = input("Enter Choice: ")

            if choice == "1":
                amount = float(input("Amount: "))
                account.deposit(amount)

            elif choice == "2":
                amount = float(input("Amount: "))
                account.withdraw(amount)

            elif choice == "3":
                account.show_balance()

            elif choice == "4":
                self.transfer_money(account)

            elif choice == "5":
                account.show_history()

            elif choice == "6":
                print("Logged Out!")
                break

            else:
                print("Invalid Choice!")

    def main_menu(self):
        while True:
            print("\n===== BANK MANAGEMENT SYSTEM =====")
            print("1. Create Account")
            print("2. Login")
            print("3. Exit")

            choice = input("Enter Choice: ")

            if choice == "1":
                self.create_account()

            elif choice == "2":
                self.login()

            elif choice == "3":
                print("Thank You!")
                break

            else:
                print("Invalid Choice!")


bank = Bank()
bank.main_menu()
